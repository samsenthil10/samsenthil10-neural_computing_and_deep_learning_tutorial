# %% [markdown]
# # RNN for Time Series
#
# RNNs are used for sequence modeling. This tutorial will look at a time series data to be modeled and predicted using RNNs.

# %%
#
# Import Libraries
#

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We will use retail data for time-series modeling.
#
# Link to the dataset:
#  https://fred.stlouisfed.org/series/MRTSSM448USN
#
# Information about the Advance Monthly Retail Sales Survey can be found on the Census website at:
# https://www.census.gov/retail/marts/about_the_surveys.html
#
# Release: Advance Monthly Sales for Retail and Food Services
# Units:  Millions of Dollars, Not Seasonally Adjusted
# Frequency:  Monthly
#
# Suggested Citation:
# U.S. Census Bureau, Advance Retail Sales: Clothing and Clothing Accessory Stores [RSCCASN], retrieved from FRED, Federal Reserve Bank of St. Louis; https://fred.stlouisfed.org/series/RSCCASN, November 16, 2019.
#
# https://fred.stlouisfed.org/series/RSCCASN

# %% [markdown]
# ### Read data first -  Use index_col = 'DATE' and 'parse_dates = True' as a parameter.

# %%
# Your code to read data
data = pd.read_csv("MRTSSM448USN.csv", index_col="DATE", parse_dates=True)
# Print first few rows of data
data.head()
# Out:
#             MRTSSM448USN
# DATE
# 1992-01-01        6938.0
# 1992-02-01        7524.0
# 1992-03-01        8475.0
# 1992-04-01        9401.0
# 1992-05-01        9558.0

# %% [markdown]
# Does the sales column has any name?
#
# If no, set the name of the colum as 'Sales'.

# %%
# Set name of column as 'Sales'. Use - df.columns 
data.rename(columns={'MRTSSM448USN':'Sales'}, inplace=True)
data.columns
# Out:
# Index(['Sales'], dtype='object')

# %% [markdown]
# Plot your data - Year vs Sales

# %%
# Your code to plot Year vs Sales. Use either matplot library of pandas dataframe.
data.plot()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# ### Next we will do Train Test Split.
#
# We will use last 1.5 year (18 month) samples for testing. Rest is for training.

# %%
# Assign variable test size = 18
# Store length of data in variable length.
# store training size in varialable train_size (Remember training size = total size - test_size)

test_size = 18
total_size = len(data)
training_size = total_size - test_size

# %% [markdown]
# Now, we will find the indexes of the test data. Remember, these are the last 18 indexes in the pandas dataframe.

# %%
#Assign the start of test index in data frame to variable test_index.  Remember, it is equal to the length of dataframe - test size

# %% [markdown]
# Next, we will separate train and test datasets.

# %%
# Store all data from 0 to test_index in variable train. Hint - Use df.iloc.
# Store everthing from test_index to the last sample in test variable. Hint - Use df.iloc.

train = data.iloc[:training_size]
test = data.iloc[training_size:]

# %%
# Print the size of the train data
# Print the size of the test data
# Print the train data
# Print the test data

print(train.shape)
print(train)
print(test.shape)
print(test)
# Out:
# (366, 1)
#               Sales
# DATE
# 1992-01-01   6938.0
# 1992-02-01   7524.0
# 1992-03-01   8475.0
# 1992-04-01   9401.0
# 1992-05-01   9558.0
# ...             ...
# 2022-02-01  20152.0
# 2022-03-01  25347.0
# 2022-04-01  25539.0
# 2022-05-01  26470.0
# 2022-06-01  24701.0
#
# [366 rows x 1 columns]
# (18, 1)
#               Sales
# DATE
# 2022-07-01  24904.0
# 2022-08-01  26049.0
# 2022-09-01  23629.0
# 2022-10-01  24787.0
# 2022-11-01  28645.0
# 2022-12-01  39883.0
# 2023-01-01  19405.0
# 2023-02-01  20937.0
# 2023-03-01  24963.0
# 2023-04-01  24700.0
# 2023-05-01  26557.0
# 2023-06-01  24809.0
# 2023-07-01  25364.0
# 2023-08-01  27143.0
# 2023-09-01  23840.0
# 2023-10-01  24438.0
# 2023-11-01  29150.0
# 2023-12-01  41228.0

# %% [markdown]
# ### In Neural Networks, we need to Scale Data between 0-1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
#
# Check if the data has been scaled properly
#

print(scaled_train)
print(scaled_test)
# Out:
# [[0.11688819]
#  [0.13325142]
#  [0.15980677]
#  [0.18566402]
#  [0.19004803]
#  [0.17954875]
#  [0.17734279]
#  [0.21671507]
#  [0.19046688]
#  [0.20948285]
#  [0.23553557]
#  [0.43680889]
#  [0.1326371 ]
#  [0.13325142]
#  [0.16793254]
#  [0.19867642]
#  [0.20414945]
#  [0.19219815]
#  [0.196638  ]
#  [0.21992628]
#  [0.16452586]
#  [0.37381325]
#  [0.41184519]
#  [0.44122082]
#  [0.4346867 ]
#  [0.46931196]
#  [0.5024852 ]
#  [0.79414721]
#  [0.3492684 ]
#  [0.36741874]
#  [0.57863286]
#  [0.56444767]
#  [0.63841729]
#  [0.60348487]
#  [0.62015526]
#  [0.6153524 ]
#  [0.54716296]
#  [0.59505194]
#  [0.7145091 ]
#  [1.        ]
#  [0.42066905]
#  [0.48587066]
#  [0.63093377]
#  [0.6362951 ]
#  [0.66229197]
#  [0.61289512]]
# [[0.61856361]
#  [0.65053613]
#  [0.58296102]
#  [0.61529655]
#  [0.7230258 ]
#  [1.03683123]
#  [0.46501173]
#  [0.50779068]
#  [0.6202111 ]
#  [0.6128672 ]
#  [0.66472132]
#  [0.61591087]
#  [0.63140847]
#  [0.68108455]
#  [0.5888529 ]
#  [0.60555121]
#  [0.73712722]
#  [1.07438847]]

# %% [markdown]
# # Time Series Generator
#
# This class takes in a sequence of data-points gathered at
# equal intervals, along with time series parameters such as
# stride, length of history, etc., to produce batches for
# training/validation.
#
# #### Arguments
#     data: Indexable generator (such as list or Numpy array)
#         containing consecutive data points (timesteps).
#         The data should be at 2D, and axis 0 is expected
#         to be the time dimension.
#     targets: Targets corresponding to timesteps in `data`.
#         It should have same length as `data`.
#     length: Length of the output sequences (in number of timesteps).
#     sampling_rate: Period between successive individual timesteps
#         within sequences. For rate `r`, timesteps
#         `data[i]`, `data[i-r]`, ... `data[i - length]`
#         are used for create a sample sequence.
#     stride: Period between successive output sequences.
#         For stride `s`, consecutive output samples would
#         be centered around `data[i]`, `data[i+s]`, `data[i+2*s]`, etc.
#     start_index: Data points earlier than `start_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     end_index: Data points later than `end_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     shuffle: Whether to shuffle output samples,
#         or instead draw them in chronological order.
#     reverse: Boolean: if `true`, timesteps in each output sample will be
#         in reverse chronological order.
#     batch_size: Number of timeseries samples in each batch
#         (except maybe the last one).

# %% [markdown]
# # We will use 12 months as input and then predict the next month out

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
length = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=1)

# %%
X, y = generator[0]

print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.11688819 0.13325142 0.15980677 0.18566402 0.19004803 0.17954875
#  0.17734279 0.21671507 0.19046688 0.20948285 0.23553557 0.43680889]
# Predict this y:
#  [[0.1326371]]

# %% [markdown]
# ### Create the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import GRU

import tensorflow as tf

# %%
# We're only using one feature in our time series
n_features = 1

# %% [markdown]
# # Define your own models.
#
# Use 1. SimpleRNN, LSTM, or GRU neural network.
#
# APIs:
# https://keras.io/api/layers/recurrent_layers/

# %%
# 
# Your code to create your own model
#

model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 56,001
# Trainable params: 56,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ### EarlyStopping and creating a Validation Generator
#
# NOTE: The scaled_test dataset size MUST be greater than your length chosen for your batches. Review video for more info on this.

# %%
validation_generator = TimeseriesGenerator(scaled_test, scaled_test, length=length, batch_size=1)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Your code to create an object early-stop.
early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose = 1)

checkpoint_dir = './checkpoints/'
checkpoint_filepath = checkpoint_dir+"/"+'model_checkpoint_{epoch:02d}.h5'

model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

# %% [markdown]
# Now, fit your model.

# %%
# Your code to fit your model.

history = model.fit(generator, verbose = 1, callbacks=[early_stop, model_checkpoint], validation_data=validation_generator, epochs = 100)
# Out:
# Epoch 1/100
# 332/354 [===========================>..] - ETA: 0s - loss: 0.0214
# Epoch 1: val_loss improved from inf to 0.02753, saving model to ./checkpoints\model_checkpoint_01.h5
# 354/354 [==============================] - 2s 3ms/step - loss: 0.0214 - val_loss: 0.0275
# Epoch 2/100
# 352/354 [============================>.] - ETA: 0s - loss: 0.0155
# Epoch 2: val_loss did not improve from 0.02753
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0154 - val_loss: 0.0296
# Epoch 3/100
# 330/354 [==========================>...] - ETA: 0s - loss: 0.0132
# Epoch 3: val_loss did not improve from 0.02753
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0152 - val_loss: 0.0675
# Epoch 4/100
# 348/354 [============================>.] - ETA: 0s - loss: 0.0119
# Epoch 4: val_loss improved from 0.02753 to 0.00939, saving model to ./checkpoints\model_checkpoint_04.h5
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0094
# Epoch 5/100
# 335/354 [===========================>..] - ETA: 0s - loss: 0.0070
# Epoch 5: val_loss did not improve from 0.00939
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0071 - val_loss: 0.0219
# Epoch 6/100
# 330/354 [==========================>...] - ETA: 0s - loss: 0.0059
# Epoch 6: val_loss improved from 0.00939 to 0.00399, saving model to ./checkpoints\model_checkpoint_06.h5
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0062 - val_loss: 0.0040
# Epoch 7/100
# 344/354 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 7: val_loss did not improve from 0.00399
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.0045
# Epoch 8/100
# 336/354 [===========================>..] - ETA: 0s - loss: 0.0049
# Epoch 8: val_loss did not improve from 0.00399
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.0095
# Epoch 9/100
# 354/354 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 9: val_loss improved from 0.00399 to 0.00197, saving model to ./checkpoints\model_checkpoint_09.h5
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 10/100
# 342/354 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 10: val_loss did not improve from 0.00197
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0046 - val_loss: 0.0036
# Epoch 11/100
# 324/354 [==========================>...] - ETA: 0s - loss: 0.0047
# Epoch 11: val_loss improved from 0.00197 to 0.00122, saving model to ./checkpoints\model_checkpoint_11.h5
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0012
# Epoch 12/100
# 344/354 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 12: val_loss improved from 0.00122 to 0.00101, saving model to ./checkpoints\model_checkpoint_12.h5
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 13/100
# 340/354 [===========================>..] - ETA: 0s - loss: 0.0038
# Epoch 13: val_loss did not improve from 0.00101
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0017
# Epoch 14/100
# 336/354 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 14: val_loss did not improve from 0.00101
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 15/100
# 330/354 [==========================>...] - ETA: 0s - loss: 0.0033
# Epoch 15: val_loss improved from 0.00101 to 0.00073, saving model to ./checkpoints\model_checkpoint_15.h5
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 7.2694e-04
# Epoch 16/100
# 351/354 [============================>.] - ETA: 0s - loss: 0.0032
# Epoch 16: val_loss did not improve from 0.00073
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 17/100
# 333/354 [===========================>..] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss did not improve from 0.00073
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 7.6908e-04
# Epoch 18/100
# 332/354 [===========================>..] - ETA: 0s - loss: 0.0023
# Epoch 18: val_loss did not improve from 0.00073
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 19/100
# 345/354 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 19: val_loss did not improve from 0.00073
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0093
# Epoch 20/100
# 347/354 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 20: val_loss did not improve from 0.00073
# 354/354 [==============================] - 1s 2ms/step - loss: 0.0028 - val_loss: 0.0076
# Epoch 20: early stopping

# %%
# Get Losses from dataframe (hint - model.history.history)- See previous week tutorial.
# Plot losses in the dataframe.

losses = pd.DataFrame(model.history.history)
plt.figure(figsize=(20,20))
losses[['loss','val_loss']].plot(color=['red', 'green'])
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluate on Test Data

# %%
first_eval_batch = scaled_train[-length:]

# %%
n_input = 12
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))
model.predict(first_eval_batch)
# Out:
# 1/1 [==============================] - 0s 171ms/step
# array([[0.6870978]], dtype=float32)

# %%
# compare with the true result:
scaled_test[0]
# Out:
# array([0.61856361])

# %% [markdown]
# #### Try predicting the series!

# %%
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for 
    # grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 15ms/step

# %% [markdown]
# ## Inverse Transformations and Compare

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
# IGNORE WARNINGS
test['Predictions'] = true_predictions
true_predictions = test['Predictions'].copy()
true_predictions
# Out:
# C:\Users\sasen\AppData\Local\Temp\ipykernel_21924\1035674157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions
# DATE
# 2022-07-01    27358.345979
# 2022-08-01    27939.708756
# 2022-09-01    26487.491831
# 2022-10-01    27941.915892
# 2022-11-01    31558.932554
# 2022-12-01    36930.567339
# 2023-01-01    21998.329612
# 2023-02-01    23443.933665
# 2023-03-01    26562.143852
# 2023-04-01    27587.969302
# 2023-05-01    29019.171468
# 2023-06-01    27884.995674
# 2023-07-01    30325.621319
# 2023-08-01    31509.844043
# 2023-09-01    30679.602063
# 2023-10-01    32398.752311
# 2023-11-01    35696.816385
# 2023-12-01    39476.332947
# Name: Predictions, dtype: float64

# %% [markdown]
# # Check and plot predictions

# %%
# Print the test variable.
test
# Out:
#               Sales   Predictions
# DATE
# 2022-07-01  24904.0  27358.345979
# 2022-08-01  26049.0  27939.708756
# 2022-09-01  23629.0  26487.491831
# 2022-10-01  24787.0  27941.915892
# 2022-11-01  28645.0  31558.932554
# 2022-12-01  39883.0  36930.567339
# 2023-01-01  19405.0  21998.329612
# 2023-02-01  20937.0  23443.933665
# 2023-03-01  24963.0  26562.143852
# 2023-04-01  24700.0  27587.969302
# 2023-05-01  26557.0  29019.171468
# 2023-06-01  24809.0  27884.995674
# 2023-07-01  25364.0  30325.621319
# 2023-08-01  27143.0  31509.844043
# 2023-09-01  23840.0  30679.602063
# 2023-10-01  24438.0  32398.752311
# 2023-11-01  29150.0  35696.816385
# 2023-12-01  41228.0  39476.332947

# %%
# Your code to plot actual sales and predictions.
plt.figure(figsize=(10, 10))
plt.plot(true_predictions, label='Actual Stock Prices')
plt.plot(test, label='Predicted Stock Prices')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Actual vs. Predicted Stock Prices')
plt.legend()

# Show plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Retrain and Forecasting

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(data)

# %%
length = 12 # Length of the output sequences (in number of timesteps)
generator = TimeseriesGenerator(scaled_full_data, 
                                scaled_full_data, length=length, batch_size=1)

# %%
#
# Use any neural network model based on RNN
#
# Create the model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(length, n_features)))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 100)               40800
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 50)                5050
#
#  dense_5 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 56,001
# Trainable params: 56,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(optimizer='adam', loss='mse')

# %%
# use early_stop
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %%
# fit the model
history = model.fit(generator, verbose = 1, callbacks=[early_stop], validation_data=validation_generator, epochs = 100)
# Out:
# Epoch 1/100
# 372/372 [==============================] - 2s 3ms/step - loss: 0.0214 - val_loss: 0.0581
# Epoch 2/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0139 - val_loss: 0.0241
# Epoch 3/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0104 - val_loss: 0.0050
# Epoch 4/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0183
# Epoch 5/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0071 - val_loss: 0.0155
# Epoch 6/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.0039
# Epoch 7/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.0077
# Epoch 8/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 9/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0038 - val_loss: 0.0124
# Epoch 10/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 7.6127e-04
# Epoch 11/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 5.0838e-04
# Epoch 12/100
# 372/372 [==============================] - 1s 3ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 13/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0239
# Epoch 14/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0017
# Epoch 15/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 16/100
# 372/372 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0027

# %%
forecast = []
# Replace periods with whatever forecast length you want
periods = 12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(periods):
    
    # get prediction 1 time stamp ahead ([0] is for  grabbing just the number instead of [array])
    prediction_i = model.predict(current_batch)[0]
    
    # store prediction forecast.append(current_pred) 
    forecast.append(prediction_i) 

    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[prediction_i]],axis=1)
# Out:
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step

# %%
forecast = scaler.inverse_transform(forecast)

# %% [markdown]
# ### Creating new timestamp index with pandas.

# %%
data
# Out:
#               Sales
# DATE
# 1992-01-01   6938.0
# 1992-02-01   7524.0
# 1992-03-01   8475.0
# 1992-04-01   9401.0
# 1992-05-01   9558.0
# ...             ...
# 2023-08-01  27143.0
# 2023-09-01  23840.0
# 2023-10-01  24438.0
# 2023-11-01  29150.0
# 2023-12-01  41228.0
#
# [384 rows x 1 columns]

# %%
forecast_index = pd.date_range(start='2024-01-01',periods=periods,freq='MS')

# %%
forecast_df = pd.DataFrame(data=forecast,index=forecast_index,
                           columns=['Forecast'])

# %%
forecast_df
# Out:
#                 Forecast
# 2024-01-01  21141.461112
# 2024-02-01  22433.229449
# 2024-03-01  25292.653934
# 2024-04-01  25376.290324
# 2024-05-01  26811.230107
# 2024-06-01  25831.246501
# 2024-07-01  26251.065661
# 2024-08-01  27625.010348
# 2024-09-01  25531.752575
# 2024-10-01  25859.608420
# 2024-11-01  29536.294615
# 2024-12-01  42088.169639

# %%
# Plot sales - Values in dataframe
data.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Plot forecast - Values in forecast_df
forecast_df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Joining pandas plots
#
# https://stackoverflow.com/questions/13872533/plot-different-dataframes-in-the-same-figure

# %%
ax = data.plot()
forecast_df.plot(ax=ax)
# Out:
# <Axes: xlabel='DATE'>

# %%
ax = data.plot()
forecast_df.plot(ax=ax)
plt.xlim('2022-01-01','2025-01-01')
# Out:
# (624.0, 660.0)

# %% [markdown]
# # Try the same example with a LSTM and GRU!
# Hint: Use LSTM instead of SimpleRNN!
